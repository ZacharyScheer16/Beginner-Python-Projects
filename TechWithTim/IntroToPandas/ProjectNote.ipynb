# %%
from itertools import groupby

import pandas as pd

df = pd.read_csv("New.csv")

# %%
df.columns
# Out:
# Index(['OrderID', 'CustomerName', 'Product', 'Category', 'Quantity', 'Price',
#        'OrderDate', 'Shipped', 'Country'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# OrderID         0
# CustomerName    0
# Product         0
# Category        0
# Quantity        0
# Price           3
# OrderDate       0
# Shipped         0
# Country         0
# dtype: int64

# %%
df.groupby("Country")['Price'].sum()
# Out:
# Country
# Australia      361.99
# Canada        2172.45
# France        1559.47
# Germany       2262.98
# U.S.A         1385.00
# UK            1595.48
# USA          17619.94
# germany         83.00
# usa           1419.99
# Name: Price, dtype: float64

# %%
df.groupby("Category")["Price"].mean()
# Out:
# Category
# Apparel         49.733830
# Electronics    460.201296
# Home Goods      28.198500
# Media           18.000000
# Name: Price, dtype: float64

# %%
df[df['Shipped'] == 'No'].groupby('Country')['OrderID'].count()
# Out:
# Country
# Canada      8
# France      4
# Germany     4
# U.S.A       1
# UK         11
# USA        10
# germany     1
# Name: OrderID, dtype: int64

# %%
df.groupby('Country')['OrderID'].count()
# Out:
# Country
# Australia     5
# Canada       28
# France       21
# Germany      19
# U.S.A         4
# UK           29
# USA          40
# germany       3
# usa           3
# Name: OrderID, dtype: int64

# %%
df['OrderDate'] = pd.to_datetime(df['OrderDate']) #makes data type date time, not string

# %%
df['OrderMonth'] = df['OrderDate'].dt.month_name()

# %%
df.head()
# Out:
#    OrderID    CustomerName       Product     Category  Quantity    Price  \
# 0     1001      John Smith        Laptop  Electronics         1  1200.00
# 1     1002   Alice Johnson      Keyboard  Electronics         2    75.50
# 2     1003    Robert Brown       T-Shirt      Apparel         5    25.00
# 3     1004     Emily Davis  Coffee Maker   Home Goods         1    89.99
# 4     1005  Michael Wilson     Mouse Pad  Electronics        10    10.00
#
#    OrderDate Shipped  Country OrderMonth
# 0 2024-06-01     Yes      USA       June
# 1 2024-06-01      No   Canada       June
# 2 2024-06-02     Yes       UK       June
# 3 2024-06-03     Yes      usa       June
# 4 2024-06-03     Yes  Germany       June

# %%
# CODE TO RUN:
df.groupby('Product')['Quantity'].sum().sort_values(ascending=True)
# Out:
# Product
# Desk Lamp          1
# Dress              1
# Coffee Maker       1
# Router             1
# Smartwatch         2
# Keyboard           3
# Jacket             4
# Speakers           4
# Sweater            4
# Webcam             4
# Pants              5
# Running Shoes      5
# Toaster            5
# Blender            5
# Charging Dock      5
# Software           5
# Storage Bin        6
# Hat                6
# Gloves             6
# External Drive     6
# Jeans              7
# Laptop             7
# Scarf              8
# Headphones         9
# Monitor           10
# Candle Set        10
# Mug               11
# Picture Frame     12
# Book              15
# T-Shirt           16
# Pillow            17
# Mouse Pad         18
# Socks             23
# USB Cable         32
# Name: Quantity, dtype: int64

# %%
# CODE TO RUN:
df[(df['Country'] == 'USA') & (df['Category'] == 'Apparel')]
# Out:
#      OrderID     CustomerName  Product Category  Quantity  Price  OrderDate  \
# 11      1012  Maria Hernandez    Socks  Apparel        12    8.5 2024-06-07
# 34      1035     Logan Walker  Sweater  Apparel        -2   65.0 2024-06-23
# 47      1048     Jackson Hall    Jeans  Apparel         1   45.0 2024-07-02
# 79      1080     Isaac Nelson  T-Shirt  Apparel         1   25.0 2024-08-03
# 87      1088   Isabella Baker  Sweater  Apparel         1   65.0 2024-08-11
# 91      1092     Grace Foster   Gloves  Apparel         1   22.0 2024-08-15
# 97      1098      Sofia Perez      Hat  Apparel         1   20.0 2024-08-21
# 113     1113     Grace Foster    Socks  Apparel         1    8.5 2024-09-05
# 126     1126     Logan Walker      Hat  Apparel         1   20.0 2024-09-18
#
#     Shipped Country OrderMonth
# 11      Yes     USA       June
# 34       No     USA       June
# 47      Yes     USA       July
# 79      Yes     USA     August
# 87       No     USA     August
# ...

# %%
df['OrderWeekday'] = df['OrderDate'].dt.day_name()

# %%
df.groupby('OrderWeekday')['Price'].mean().sort_values(ascending=False)
# Out:
# OrderWeekday
# Sunday       765.400000
# Saturday     250.020000
# Wednesday    101.402381
# Tuesday       81.303913
# Thursday      75.249000
# Monday        61.223500
# Friday        30.588636
# Name: Price, dtype: float64

# %%
df[(df['OrderWeekday'] == 'Monday') & (df['Quantity'] == 1)]
# Out:
#      OrderID      CustomerName        Product     Category  Quantity   Price  \
# 3       1004       Emily Davis   Coffee Maker   Home Goods         1   89.99
# 24      1025     Andrew Harris       Software  Electronics         1   99.99
# 25      1026     Victoria Reed         Jacket      Apparel         1  130.00
# 35      1036        Mason Gray         Router  Electronics         1   79.99
# 46      1047  Evelyn Rodriguez       Keyboard  Electronics         1   75.50
# 53      1054    Michael Wilson        Blender   Home Goods         1     NaN
# 60      1061   Maria Hernandez           Book        Media         1   18.00
# 74      1075     Victoria Reed          Pants      Apparel         1   55.00
# 81      1082    William Flores  Running Shoes      Apparel         1  110.00
# 88      1089        Noah Adams         Pillow   Home Goods         1   20.00
# 95      1096     Victoria Reed     Candle Set   Home Goods         1   28.00
# ...

# %%
df[['Price', 'Quantity']].describe()
# Out:
#               Price    Quantity
# count    149.000000  152.000000
# mean     191.008725    1.802632
# std     1001.929517    2.058867
# min      -10.000000   -2.000000
# 25%       18.000000    1.000000
# 50%       39.990000    1.000000
# 75%       99.990000    2.000000
# max    12000.000000   15.000000

# %%
# CODE TO RUN:
df['Product'].value_counts().head(5)
# Out:
# Product
# Pillow        9
# Monitor       9
# Book          8
# Candle Set    8
# Laptop        7
# Name: count, dtype: int64

# %%
# CODE TO RUN:
df[['Price', 'Quantity']].corr()
# Out:
#             Price  Quantity
# Price     1.00000  -0.06697
# Quantity -0.06697   1.00000
